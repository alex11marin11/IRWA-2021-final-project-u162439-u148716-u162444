# %% [raw]
# Alex Marin Felices    219305  u162444
#
# Mireia Palou Tort     219331  u162439
#
# Blanca Ruano Miranda  205722  u148716

# %% [markdown]
# # Part 1: Text Processing

# %%
import pandas as pd
import re
import json

import nltk
nltk.download('stopwords')

from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mirei\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Open txt and save it as a pandas dataframe
with open('inputs/dataset_tweets_WHO.txt') as f:
    json_data = json.load(f)
    
data = pd.DataFrame(json_data).transpose()
#data.head()

# %%
#function to process the tweets
def build_terms(line):
    """
    Preprocess the article text (title + body) removing stop words, stemming,
    transforming in lowercase and return the tokens of the text.
    
    Argument:
    line -- string (text) to be preprocessed
    
    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """
    
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    
    ## START CODE
    line= str.lower(line) # Transform in lowercase
    line = re.sub('[^\w\s]','', line) # removing punctuation
    line= line.split() # Tokenization
    line= [l for l in line if l not in stop_words] # remove stopwords
    line= [stemmer.stem(word) for word in line] # stemming
    

    ## END CODE
    return line

# %%
# apply function to the corresponding column
data['full_text'] = data['full_text'].map(lambda x: build_terms(x))

# %%
#this is how the data looks like now
data.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Wed Oct 13 09:15:58 +0000 2021  1448215930178310144  1448215930178310144
# 1  Wed Oct 13 08:46:17 +0000 2021  1448208458604584960  1448208458604584960
# 2  Wed Oct 13 07:53:28 +0000 2021  1448195167048118274  1448195167048118274
# 3  Wed Oct 13 05:47:26 +0000 2021  1448163447678676992  1448163447678676992
# 4  Wed Oct 13 05:47:10 +0000 2021  1448163383493136385  1448163383493136385
#
#                                            full_text truncated  \
# 0  [intern, day, disast, risk, reduct, openwho, l...     False
# 1  [covid19, shown, health, emerg, disast, affect...     False
# 2  [intern, day, disast, risk, reduct, better, re...     False
# 3  [rt, whoafro, congratul, algeria, algeria, 16t...     False
# 4  [rt, opsom, si, está, completament, vacunado, ...     False
#
#   display_text_range                                           entities  \
# 0           [0, 274]  {'hashtags': [{'text': 'OpenWHO', 'indices': [...
# 1           [0, 241]  {'hashtags': [{'text': 'COVID19', 'indices': [...
# 2           [0, 283]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3           [0, 140]  {'hashtags': [{'text': 'Algeria', 'indices': [...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1448215398814560259, 'id_str...
# 1  {'media': [{'id': 1448208218463875077, 'id_str...
# 2  {'media': [{'id': 1448194582106234882, 'id_str...
# 3                                                NaN
# 4                                                NaN
#
#                                               source in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...   1448208458604584960
# 1  <a href="https://mobile.twitter.com" rel="nofo...   1448195167048118274
# 2  <a href="https://mobile.twitter.com" rel="nofo...                  None
# 3  <a href="http://twitter.com/download/iphone" r...                  None
# 4  <a href="http://twitter.com/download/iphone" r...                  None
#
#    ... favorite_count favorited retweeted possibly_sensitive lang  \
# 0  ...             52     False     False              False   en
# 1  ...            119     False     False              False   en
# 2  ...            300     False     False              False   en
# 3  ...              0     False     False                NaN   en
# 4  ...              0     False     False                NaN   es
#
#                                     retweeted_status quoted_status_id  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3  {'created_at': 'Tue Oct 12 17:05:04 +0000 2021...              NaN
# 4  {'created_at': 'Tue Oct 12 18:22:00 +0000 2021...              NaN
#
#   quoted_status_id_str quoted_status_permalink quoted_status
# 0                  NaN                     NaN           NaN
# 1                  NaN                     NaN           NaN
# 2                  NaN                     NaN           NaN
# 3                  NaN                     NaN           NaN
# 4                  NaN                     NaN           NaN
#
# [5 rows x 31 columns]
